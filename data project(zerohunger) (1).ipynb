# %%
##importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wrn
wrn.filterwarnings('ignore')

# %%
import os
os.chdir("C:\\Users\\HP\\Downloads")

# %%
df=pd.read_csv('sdg_index_2000-2022.csv')

# %%
df.shape
# Out:
# (4140, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_code     4140 non-null   object
#  1   country          4140 non-null   object
#  2   year             4140 non-null   int64
#  3   sdg_index_score  4140 non-null   float64
#  4   goal_1_score     4140 non-null   float64
#  5   goal_2_score     4140 non-null   float64
#  6   goal_3_score     4140 non-null   float64
#  7   goal_4_score     4140 non-null   float64
#  8   goal_5_score     4140 non-null   float64
#  9   goal_6_score     4140 non-null   float64
#  10  goal_7_score     4140 non-null   float64
#  11  goal_8_score     4140 non-null   float64
#  12  goal_9_score     4140 non-null   float64
#  13  goal_10_score    4140 non-null   float64
#  14  goal_11_score    4140 non-null   float64
#  15  goal_12_score    4140 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['country_code', 'country', 'year', 'sdg_index_score', 'goal_1_score',
#        'goal_2_score', 'goal_3_score', 'goal_4_score', 'goal_5_score',
#        'goal_6_score', 'goal_7_score', 'goal_8_score', 'goal_9_score',
#        'goal_10_score', 'goal_11_score', 'goal_12_score', 'goal_13_score',
#        'goal_14_score', 'goal_15_score', 'goal_16_score', 'goal_17_score'],
#       dtype='object')

# %%
df.describe(include='object')
# Out:
#        country_code      country
# count          4140         4140
# unique          180          180
# top             AFG  Afghanistan
# freq             23           23

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
# Out:
# country_code
# ['AFG' 'ALB' 'DZA' 'AGO' 'ARG' 'ARM' 'AUS' 'AUT' 'AZE' 'BHS' 'BHR' 'BGD'
#  'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BTN' 'BOL' 'BIH' 'BWA' 'BRA' 'BRN' 'BGR'
#  'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN' 'CAF' 'TCD' 'CHL' 'CHN' 'COL' 'COM'
#  'COD' 'COG' 'CRI' 'CIV' 'HRV' 'CUB' 'CYP' 'CZE' 'DNK' 'DJI' 'DOM'
#  '_E_S_Asia' '_E_Euro_Asia' 'ECU' 'EGY' 'SLV' 'EST' 'SWZ' 'ETH' 'FJI'
#  'FIN' 'FRA' 'GAB' 'GMB' 'GEO' 'DEU' 'GHA' 'GRC' 'GTM' 'GIN' 'GUY' 'HTI'
#  '_HIC' 'HND' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'ISR' 'ITA' 'JAM'
#  'JPN' 'JOR' 'KAZ' 'KEN' 'KOR' 'KWT' 'KGZ' 'LAO' '_LAC' 'LVA' 'LBN' 'LSO'
#  'LBR' 'LTU' '_LIC_LMIC' '_LMIC' '_LIC' 'LUX' 'MDG' 'MWI' 'MYS' 'MDV'
#  'MLI' 'MLT' 'MRT' 'MUS' 'MEX' '_MENA' 'MDA' 'MNG' 'MNE' 'MAR' 'MOZ' 'MMR'
#  'NAM' 'NPL' 'NLD' 'NZL' 'NIC' 'NER' 'NGA' 'MKD' 'NOR' '_Oceania' '_OECD'
#  'OMN' 'PAK' 'PAN' 'PNG' 'PRY' 'PER' 'PHL' 'POL' 'PRT' 'QAT' 'ROU' 'RUS'
#  'RWA' 'STP' 'SAU' 'SEN' 'SRB' 'SLE' 'SGP' 'SVK' 'SVN' '_SIDS' 'SOM' 'ZAF'
# ...

# %%
df.isnull().sum()
# Out:
# country_code       0
# country            0
# year               0
# sdg_index_score    0
# goal_1_score       0
# goal_2_score       0
# goal_3_score       0
# goal_4_score       0
# goal_5_score       0
# goal_6_score       0
# goal_7_score       0
# goal_8_score       0
# goal_9_score       0
# goal_10_score      0
# goal_11_score      0
# goal_12_score      0
# goal_13_score      0
# goal_14_score      0
# goal_15_score      0
# goal_16_score      0
# goal_17_score      0
# dtype: int64

# %%
df.describe()
# Out:
#               year  sdg_index_score  goal_1_score  goal_2_score  goal_3_score  \
# count  4140.000000      4140.000000   4140.000000   4140.000000   4140.000000
# mean   2011.000000        63.685435     64.815628     57.735531     64.045652
# std       6.634051        10.776469     36.098836     11.121524     22.354993
# min    2000.000000        36.000000      0.000000      7.700000      5.900000
# 25%    2005.000000        55.075000     31.500000     52.400000     44.800000
# 50%    2011.000000        65.100000     81.000000     58.900000     70.200000
# 75%    2017.000000        72.000000     98.600000     65.300000     81.300000
# max    2022.000000        86.800000    100.000000     83.400000     97.300000
#
#        goal_4_score  goal_5_score  goal_6_score  goal_7_score  goal_8_score  \
# count   4140.000000   4140.000000   4140.000000   4140.000000   4140.000000
# mean      71.990048     55.803309     63.963188     57.340966     69.839493
# ...

# %%
df['year'].plot(kind='box')
# Out:
# <Axes: >

# %%
#data cleaning with python and pandas

# %%
missing_value=['0.0','0']
df=pd.read_csv('sdg_index_2000-2022.csv',na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# country_code         0
# country              0
# year                 0
# sdg_index_score      0
# goal_1_score       405
# goal_2_score         0
# goal_3_score         0
# goal_4_score        42
# goal_5_score         0
# goal_6_score         0
# goal_7_score         0
# goal_8_score         0
# goal_9_score        14
# goal_10_score      427
# goal_11_score        0
# goal_12_score        0
# goal_13_score       26
# goal_14_score      943
# goal_15_score        0
# goal_16_score        0
# goal_17_score        0
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
#sample dada: years and hunger rates 
data={
    'year':[2010,2015,2016,2020],
    'goal_2_score':[10,40,20,40]
}
#creating a data frame 
df=pd.DataFrame(data)
#filter only the relavent columns for sdg 2
df_sdg2=df[['year','goal_2_score']]
#finding min value and corresponding year for sdg 2
min_sdg2=df_sdg2[df_sdg2['goal_2_score']==df_sdg2['goal_2_score'].min()]
#plotting the data 
plt.plot(min_sdg2['year'],min_sdg2['goal_2_score'],marker='o',markersize=10,color='r')
plt.text(min_sdg2['year'].values[0],min_sdg2['goal_2_score'].values[0],
         f'Minimum:{min_sdg2["year"].values[0]}',
         horizontalalignment='left',verticalalignment='bottom')
#adding labels and tittle
plt.xlabel('year')
plt.ylabel('SDG 2 Indicator')
plt.title('SDG 2 (zero hunger) over the years')
plt.grid(True)
plt.show()

# %%
data = {
    'Year': list(range(2000, 2021)),
    'goal_2_score': [38.8, 58, 57, 55, 54, 52, 50, 49, 48, 47, 45, 43, 41, 40, 38, 36, 34, 32, 31, 30, 28]  
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(df['Year'], df['goal_2_score'], marker='o', linestyle='-', color='b', label='SDG 2 (Zero Hunger)')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('SDG 2 Indicator')
plt.title('SDG 2 (Zero Hunger) from 2000 to 2020')
plt.grid(True)
plt.xticks(df['Year'], rotation=45)
plt.tight_layout()
plt.show()

# %%
#plotting graph in different year in different country
data = {
    'Year': [2000, 2000, 2000, 2010, 2010, 2010, 2020, 2020, 2020],
    'Country': ['Afghanistan', 'Albania', 'Angola', 'Afghanistan', 'Albania', 'Angola', 'Afghanistan', 'Albania ', 'Angola'],
    'goal_2_score': [50, 60, 55, 45, 65, 50, 40, 70, 45]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Filtering data for the years 2000 to 2020
df_filtered = df[(df['Year'] >= 2000) & (df['Year'] <= 2020)]

# Plotting the data
plt.figure(figsize=(12, 6))

# Grouping by year and country, then plotting
for year in df_filtered['Year'].unique():
    df_year = df_filtered[df_filtered['Year'] == year]
    plt.bar(df_year['Country'] + ' ' + df_year['Year'].astype(str), df_year['goal_2_score'], label=str(year))

# Adding labels and title
plt.xlabel('Country and Year')
plt.ylabel('SDG 2 Indicator')
plt.title('SDG 2 (Zero Hunger) for Multiple Countries (2000-2020)')
plt.legend(title='Year')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
countries = ['Afghanistan', 'Albania', 'Angola', 'Bahrain', 'Colombia']
hunger_values = [50, 60, 70, 80, 90]

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(hunger_values, labels=countries, autopct='%1.1f%%', startangle=140)
plt.title('Hunger Values by Country for the Year 2022')
plt.show()

# %%
#Number of zero hunger states from 2000 to 2020
years = list(range(2000, 2021))
zero_hunger_states = [47.3,47.7,46.1,46.8,46.2,46.6,47.6,49.1,49.4,49.9,50.5,51.3,52.2,52.6,53.6,51.9,52.9,53.6,54,54.1,53.8]  

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(years, zero_hunger_states, marker='o', linestyle='-', color='b')

# Add titles and labels
plt.title('Number of Zero Hunger States in India (2000-2020)')
plt.xlabel('Year')
plt.ylabel('Number of Zero Hunger States')

# Show grid
plt.grid(True)

# Show the plot
plt.show()
